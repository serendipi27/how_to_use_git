# %%
import pandas as pd

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

path = '/Users/jsha/gjai/final_project/Physionet2012_new/'
file = 'physionet2012_train.csv'

df = pd.read_csv(path+file, index_col=None)
del df['Unnamed: 0']
df.head()
# Out:
#       pid rec_time   age  Gender  ICUType  ALP  ALT  AST  Albumin  BUN  \
# 0  142219  0:00:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 1  142219  0:44:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 2  142219  1:14:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 3  142219  1:44:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 4  142219  1:54:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
#
#    Bilirubin  Cholesterol  Creatinine  FiO2  GCS  Glucose  HCO3  HCT     HR  \
# 0        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN   86.0
# 1        NaN          NaN         NaN   0.8  NaN      NaN   NaN  NaN  103.0
# 2        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  100.0
# 3        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  106.0
# 4        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  105.0
#
#     K  Lactate  Mg  Na  PaCO2  PaO2  Platelets    RR  SPO2    BT  Tropl  \
# 0 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 1 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 2 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 3 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 4 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
#
#    TroponinI  TropT  TroponinT  Urine  WBC  pH  MechVent  survival    SBP  \
# 0        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1  116.0
# 1        NaN    NaN        NaN  500.0  NaN NaN       NaN        -1  116.0
# 2        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1    0.0
# 3        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1    0.0
# 4        NaN    NaN        NaN  450.0  NaN NaN       NaN        -1  217.0
#
#      DBP    MBP  male  female  surv_los  LOS
# 0   58.0   77.0     1       0        -8    7
# 1   58.0   77.0     1       0        -8    7
# 2    0.0  224.0     1       0        -8    7
# 3    0.0  135.0     1       0        -8    7
# 4  108.0  133.0     1       0        -8    7

# %%
# 데이터 수와 환자 수 파악

print('총 데이터 수: {}'.format(len(df)))
print('총 환자 수: {}'.format(len(df.pid.unique())))
# Out:
# 총 데이터 수: 242613
# 총 환자 수: 3240

# %%
# dtype 파악
df.dtypes.value_counts()
# Out:
# float64    38
# int64       6
# object      1
# dtype: int64

# %%
df.head()
# Out:
#       pid rec_time   age  Gender  ICUType  ALP  ALT  AST  Albumin  BUN  \
# 0  142219  0:00:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 1  142219  0:44:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 2  142219  1:14:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 3  142219  1:44:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 4  142219  1:54:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
#
#    Bilirubin  Cholesterol  Creatinine  FiO2  GCS  Glucose  HCO3  HCT     HR  \
# 0        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN   86.0
# 1        NaN          NaN         NaN   0.8  NaN      NaN   NaN  NaN  103.0
# 2        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  100.0
# 3        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  106.0
# 4        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  105.0
#
#     K  Lactate  Mg  Na  PaCO2  PaO2  Platelets    RR  SPO2    BT  Tropl  \
# 0 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 1 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 2 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 3 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 4 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
#
#    TroponinI  TropT  TroponinT  Urine  WBC  pH  MechVent  survival    SBP  \
# 0        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1  116.0
# 1        NaN    NaN        NaN  500.0  NaN NaN       NaN        -1  116.0
# 2        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1    0.0
# 3        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1    0.0
# 4        NaN    NaN        NaN  450.0  NaN NaN       NaN        -1  217.0
#
#      DBP    MBP  male  female  surv_los  LOS
# 0   58.0   77.0     1       0        -8    7
# 1   58.0   77.0     1       0        -8    7
# 2    0.0  224.0     1       0        -8    7
# 3    0.0  135.0     1       0        -8    7
# 4  108.0  133.0     1       0        -8    7

# %%
# null_ratio = 0.5
# over_05 = df.notnull().sum()[(df.notnull().sum() / len(df)) > null_ratio].map(lambda x: x / len(df))

# print(f"결측치 비율이 0.5 이상인 컬럼 수: {len(over_05)}")
# over_05
# over_columns = over_05.index
# print(over_columns)

# df2 = df[over_columns]
# df2.head()

# %% [markdown]
# ## 1. 생존 유무 라벨링(0: survival, 1:death)
# - Survival > Length of stay  ⇒  Survivor
# - Survival = -1  ⇒  Survivor
# - 2 ≤ Survival ≤ Length of stay  ⇒  In-hospital death

# %%
import numpy as np
labels = np.zeros(len(df))
# labels[df.survival == -1] = 0
# labels[((2 <= df.survival) & (df.survival <= df.LOS)).index.to_list() = 1
labels[df[(2 <= df.survival) & (df.survival <= df.LOS)].index.to_list()] = 1
labels[df[df.survival > df.LOS].index.to_list()] = 0
labels[df[df.survival == -1].index.to_list()] = 0
df['labels'] = labels

cnt = df[['pid', 'labels']].drop_duplicates(['pid'])['labels'].value_counts()
print(f'num of survival: {cnt.iloc[0]} \n num of death: {cnt.iloc[1]}')
# Out:
# num of survival: 2813
#  num of death: 427

# %%
df.head()
# Out:
#       pid rec_time   age  Gender  ICUType  ALP  ALT  AST  Albumin  BUN  \
# 0  142219  0:00:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 1  142219  0:44:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 2  142219  1:14:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 3  142219  1:44:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
# 4  142219  1:54:00  52.0     0.0      3.0  NaN  NaN  NaN      NaN  NaN
#
#    Bilirubin  Cholesterol  Creatinine  FiO2  GCS  Glucose  HCO3  HCT     HR  \
# 0        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN   86.0
# 1        NaN          NaN         NaN   0.8  NaN      NaN   NaN  NaN  103.0
# 2        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  100.0
# 3        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  106.0
# 4        NaN          NaN         NaN   NaN  NaN      NaN   NaN  NaN  105.0
#
#     K  Lactate  Mg  Na  PaCO2  PaO2  Platelets    RR  SPO2    BT  Tropl  \
# 0 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 1 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 2 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 3 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
# 4 NaN      NaN NaN NaN    NaN   NaN        NaN  19.0  97.0  37.1    NaN
#
#    TroponinI  TropT  TroponinT  Urine  WBC  pH  MechVent  survival    SBP  \
# 0        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1  116.0
# 1        NaN    NaN        NaN  500.0  NaN NaN       NaN        -1  116.0
# 2        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1    0.0
# 3        NaN    NaN        NaN    NaN  NaN NaN       NaN        -1    0.0
# 4        NaN    NaN        NaN  450.0  NaN NaN       NaN        -1  217.0
#
#      DBP    MBP  male  female  surv_los  LOS  labels
# 0   58.0   77.0     1       0        -8    7     0.0
# 1   58.0   77.0     1       0        -8    7     0.0
# 2    0.0  224.0     1       0        -8    7     0.0
# 3    0.0  135.0     1       0        -8    7     0.0
# 4  108.0  133.0     1       0        -8    7     0.0

# %% [markdown]
# ## 2. 데이터 전처리 - 결측치 채우기
#  - 1. fillna(method='ffill')
#  - 2. fillna(컬럼별 median)
#  - 3. 의문점1) 결측치 비율이 0.5가 넘는 컬럼도 무리하게 결측치를 채워 사용해도 되는가?
#  - 4. 의문점2) method='ffill'을 사용하면 다른 pid의 컬럼 내용을 가져올 리는 없는가?

# %%
test = pd.DataFrame([[1,1,np.nan],
                     [2,2,np.nan],
                     [np.nan, 3, np.nan],
                     [np.nan,4,4],
                     [5,5,5],
                     [np.nan, np.nan, np.nan]])
print(test)
test2 = test.fillna(method='ffill', axis=1)
print(test2)
test3 = test2.fillna(method='bfill', axis=1)
print(test3)
# Out:
#      0    1    2
# 0  1.0  1.0  NaN
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  NaN  4.0  4.0
# 4  5.0  5.0  5.0
# 5  NaN  NaN  NaN
#      0    1    2
# 0  1.0  1.0  1.0
# 1  2.0  2.0  2.0
# 2  NaN  3.0  3.0
# 3  NaN  4.0  4.0
# 4  5.0  5.0  5.0
# 5  NaN  NaN  NaN
#      0    1    2
# 0  1.0  1.0  1.0
# 1  2.0  2.0  2.0
# 2  3.0  3.0  3.0
# 3  4.0  4.0  4.0
# 4  5.0  5.0  5.0
# 5  NaN  NaN  NaN

# %%
df2 = df.copy()
pids = df2.pid.unique()
# df2 = df.fillna(method='ffill') 
df_list = []
for pidd in pids:
    new_df = df2[df2.pid == pidd].fillna(method='ffill')
    new_df = new_df[new_df.pid == pidd].fillna(method='bfill', axis=0)
    df_list.append(new_df)
df3 = pd.concat(df_list)
df3.fillna(df3.median(), inplace=True)
# Out:
# /var/folders/j8/pjz_xxgx4xqdv4jz1jkf7nmc0000gn/T/ipykernel_1154/786383720.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3.fillna(df3.median(), inplace=True)

# %%
print(len(df3))
pd.DataFrame(df3.isnull().sum())
# Out:
# 242613
#                   0
# pid               0
# rec_time          0
# age               0
# Gender            0
# ICUType           0
# ALP               0
# ALT               0
# AST               0
# Albumin           0
# BUN               0
# Bilirubin         0
# Cholesterol       0
# Creatinine        0
# FiO2              0
# GCS               0
# Glucose           0
# HCO3              0
# HCT               0
# HR                0
# K                 0
# Lactate           0
# Mg                0
# Na                0
# PaCO2             0
# PaO2              0
# Platelets         0
# RR                0
# SPO2              0
# BT                0
# Tropl        242613
# TroponinI         0
# TropT        242613
# TroponinT         0
# Urine             0
# WBC               0
# pH                0
# MechVent          0
# survival          0
# SBP               0
# DBP               0
# MBP               0
# male              0
# female            0
# surv_los          0
# LOS               0
# labels            0

# %%
# 데이터가 단 하나도 없는 column 'Tropl', 'TropT' 제외
# 'rec_time'은 이후 padding에서 np.zeros에 string 데이터가 들어갈 수 없는 문제를 해결하기 위해 미리 제거
df4 = df3.drop(columns=['Tropl', 'TropT', 'rec_time'])
pd.DataFrame(df4.isnull().sum())
# Out:
#              0
# pid          0
# age          0
# Gender       0
# ICUType      0
# ALP          0
# ALT          0
# AST          0
# Albumin      0
# BUN          0
# Bilirubin    0
# Cholesterol  0
# Creatinine   0
# FiO2         0
# GCS          0
# Glucose      0
# HCO3         0
# HCT          0
# HR           0
# K            0
# Lactate      0
# Mg           0
# Na           0
# PaCO2        0
# PaO2         0
# Platelets    0
# RR           0
# SPO2         0
# BT           0
# TroponinI    0
# TroponinT    0
# Urine        0
# WBC          0
# pH           0
# MechVent     0
# survival     0
# SBP          0
# DBP          0
# MBP          0
# male         0
# female       0
# surv_los     0
# LOS          0
# labels       0

# %% [markdown]
# ## 3. padding
# - 기준: 70
# - pre zero-padding
# - np.zeros에 string이 들어갈 수 없기 때문에 rec_time column을 제외시키자.

# %%
maxlen = 70
col_len = len(df4.columns)
data = []
basic_col = 'pid, age, Gender, ICUType, survival, male, female, surv_los, LOS, labels'
basic_col_list = basic_col.split(', ')
basic_col_indexer = df4.columns.get_indexer(basic_col_list)
basic_col_indexer

for pid in df4.pid.drop_duplicates().to_numpy():
    if len(df4[df4.pid == pid]) >= 70:
        dummy = df4[df4.pid == pid].to_numpy().tolist()
        data.append(dummy[:maxlen])
    else:
        length = len(df4[df4.pid == pid])
        base = np.zeros((maxlen, col_len))
        for idx in basic_col_indexer:
            base[:, idx] = df4[df4.pid == pid].iloc[0, idx]
        # print(base.shape)
        dummy = df4[df4.pid == pid].to_numpy()
        # print(dummy.shape)
        base[-length:] = dummy
        # print(base.shape)
        # base[:length, 0] = pid
        # base[:length, -1] = dummy[0, -1] 
        data.append(base.tolist())
        # print(base)

# %%
data = np.array(data)
data = data.reshape((-1, len(df4.columns)))
df5 = pd.DataFrame(data, columns=df4.columns)
print(3240* 70, len(df5))
df5
# Out:
# 226800 226800
#              pid   age  Gender  ICUType   ALP   ALT   AST  Albumin   BUN  \
# 0       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 1       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 2       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 3       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 4       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# ...          ...   ...     ...      ...   ...   ...   ...      ...   ...
# 226795  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226796  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226797  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226798  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226799  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
#
#         Bilirubin  Cholesterol  Creatinine  FiO2   GCS  Glucose  HCO3   HCT  \
# 0             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 1             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 2             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 3             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 4             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# ...           ...          ...         ...   ...   ...      ...   ...   ...
# 226795        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226796        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226797        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226798        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226799        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
#
#            HR    K  Lactate   Mg     Na  PaCO2   PaO2  Platelets    RR   SPO2  \
# 0        86.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 1       103.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 2       100.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 3       106.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 4       105.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# ...       ...  ...      ...  ...    ...    ...    ...        ...   ...    ...
# 226795   93.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226796   94.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226797   85.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226798   83.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226799   83.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
#
#           BT  TroponinI  TroponinT  Urine   WBC    pH  MechVent  survival  \
# 0       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 1       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 2       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 3       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 4       37.1        2.3       0.14  450.0  11.9  7.41       1.0      -1.0
# ...      ...        ...        ...    ...   ...   ...       ...       ...
# 226795  37.2        2.3       0.14   42.0  12.9  7.42       1.0      17.0
# 226796  37.2        2.3       0.14  110.0  12.9  7.42       1.0      17.0
# 226797  36.9        2.3       0.14   80.0  12.9  7.42       1.0      17.0
# 226798  36.9        2.3       0.14   40.0  12.9  7.42       1.0      17.0
# 226799  36.9        2.3       0.14   45.0  12.9  7.42       1.0      17.0
#
#           SBP    DBP    MBP  male  female  surv_los   LOS  labels
# 0       116.0   58.0   77.0   1.0     0.0      -8.0   7.0     0.0
# 1       116.0   58.0   77.0   1.0     0.0      -8.0   7.0     0.0
# 2         0.0    0.0  224.0   1.0     0.0      -8.0   7.0     0.0
# 3         0.0    0.0  135.0   1.0     0.0      -8.0   7.0     0.0
# 4       217.0  108.0  133.0   1.0     0.0      -8.0   7.0     0.0
# ...       ...    ...    ...   ...     ...       ...   ...     ...
# 226795  118.0   66.0   85.0   1.0     0.0      -1.0  18.0     1.0
# 226796  129.0   71.0   93.0   1.0     0.0      -1.0  18.0     1.0
# 226797  114.0   65.0   84.0   1.0     0.0      -1.0  18.0     1.0
# 226798  111.0   61.0   80.0   1.0     0.0      -1.0  18.0     1.0
# 226799  109.0   62.0   80.0   1.0     0.0      -1.0  18.0     1.0
#
# [226800 rows x 43 columns]

# %%
df5.shape
df5.pid.value_counts()
df5[['pid', 'labels']].drop_duplicates(['pid'])['labels'].value_counts()
# Out:
# 0.0    2813
# 1.0     427
# Name: labels, dtype: int64

# %% [markdown]
# ## 4. Normalization

# %%
df5.head()
# Out:
#         pid   age  Gender  ICUType   ALP   ALT   AST  Albumin  BUN  Bilirubin  \
# 0  142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9  5.0        0.7
# 1  142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9  5.0        0.7
# 2  142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9  5.0        0.7
# 3  142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9  5.0        0.7
# 4  142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9  5.0        0.7
#
#    Cholesterol  Creatinine  FiO2   GCS  Glucose  HCO3   HCT     HR    K  \
# 0        153.0         0.6   0.8  15.0    104.0  28.0  35.5   86.0  3.9
# 1        153.0         0.6   0.8  15.0    104.0  28.0  35.5  103.0  3.9
# 2        153.0         0.6   0.8  15.0    104.0  28.0  35.5  100.0  3.9
# 3        153.0         0.6   0.8  15.0    104.0  28.0  35.5  106.0  3.9
# 4        153.0         0.6   0.8  15.0    104.0  28.0  35.5  105.0  3.9
#
#    Lactate   Mg     Na  PaCO2  PaO2  Platelets    RR  SPO2    BT  TroponinI  \
# 0      1.1  1.7  138.0   44.0  63.0      317.0  19.0  97.0  37.1        2.3
# 1      1.1  1.7  138.0   44.0  63.0      317.0  19.0  97.0  37.1        2.3
# 2      1.1  1.7  138.0   44.0  63.0      317.0  19.0  97.0  37.1        2.3
# 3      1.1  1.7  138.0   44.0  63.0      317.0  19.0  97.0  37.1        2.3
# 4      1.1  1.7  138.0   44.0  63.0      317.0  19.0  97.0  37.1        2.3
#
#    TroponinT  Urine   WBC    pH  MechVent  survival    SBP    DBP    MBP  \
# 0       0.14  500.0  11.9  7.41       1.0      -1.0  116.0   58.0   77.0
# 1       0.14  500.0  11.9  7.41       1.0      -1.0  116.0   58.0   77.0
# 2       0.14  500.0  11.9  7.41       1.0      -1.0    0.0    0.0  224.0
# 3       0.14  500.0  11.9  7.41       1.0      -1.0    0.0    0.0  135.0
# 4       0.14  450.0  11.9  7.41       1.0      -1.0  217.0  108.0  133.0
#
#    male  female  surv_los  LOS  labels
# 0   1.0     0.0      -8.0  7.0     0.0
# 1   1.0     0.0      -8.0  7.0     0.0
# 2   1.0     0.0      -8.0  7.0     0.0
# 3   1.0     0.0      -8.0  7.0     0.0
# 4   1.0     0.0      -8.0  7.0     0.0

# %%
import matplotlib.pyplot as plt

bins = [i for i in range(1, 100, 5)]
cats = pd.cut(df5.age, bins, labels=bins[:-1])
cats.value_counts().plot.bar()

icu_type = {1.: '관상동맥치료실', 2.: '심장수술회복실', 3.: '의료ICU', 4.: '외과ICU'}
df5.ICUType.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# y = df3.labels.copy()
# X = df3.drop(columns=['labels'])
# for i, col in enumerate(X.columns):
#     X[col] = (X[col] - X[col].mean()) / X[col].std()
#     # print(i)

# %%
# Gender 중에 -1 값을 갖는 pid가 3개 있음.
# 일단 -1을 1로 치환함.

df5.Gender.value_counts()
print(df5[df5.Gender == -1.]['pid'].unique())
df5.Gender.replace({-1.:1.0}, inplace=True)
df5.Gender.value_counts()
# Out:
# []
# 1.0    127470
# 0.0     99330
# Name: Gender, dtype: int64

# %%
df5
# Out:
#              pid   age  Gender  ICUType   ALP   ALT   AST  Albumin   BUN  \
# 0       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 1       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 2       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 3       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# 4       142219.0  52.0     0.0      3.0  75.0  31.0  48.0      2.9   5.0
# ...          ...   ...     ...      ...   ...   ...   ...      ...   ...
# 226795  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226796  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226797  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226798  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
# 226799  138581.0  53.0     1.0      4.0  75.0  31.0  48.0      2.9  18.0
#
#         Bilirubin  Cholesterol  Creatinine  FiO2   GCS  Glucose  HCO3   HCT  \
# 0             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 1             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 2             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 3             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# 4             0.7        153.0         0.6   0.8  15.0    104.0  28.0  35.5
# ...           ...          ...         ...   ...   ...      ...   ...   ...
# 226795        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226796        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226797        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226798        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
# 226799        0.7        153.0         1.1   0.4   8.0    158.0  25.0  23.4
#
#            HR    K  Lactate   Mg     Na  PaCO2   PaO2  Platelets    RR   SPO2  \
# 0        86.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 1       103.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 2       100.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 3       106.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# 4       105.0  3.9      1.1  1.7  138.0   44.0   63.0      317.0  19.0   97.0
# ...       ...  ...      ...  ...    ...    ...    ...        ...   ...    ...
# 226795   93.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226796   94.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226797   85.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226798   83.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
# 226799   83.0  3.7      1.0  2.0  134.0   42.0  197.0      177.0  19.0  100.0
#
#           BT  TroponinI  TroponinT  Urine   WBC    pH  MechVent  survival  \
# 0       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 1       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 2       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 3       37.1        2.3       0.14  500.0  11.9  7.41       1.0      -1.0
# 4       37.1        2.3       0.14  450.0  11.9  7.41       1.0      -1.0
# ...      ...        ...        ...    ...   ...   ...       ...       ...
# 226795  37.2        2.3       0.14   42.0  12.9  7.42       1.0      17.0
# 226796  37.2        2.3       0.14  110.0  12.9  7.42       1.0      17.0
# 226797  36.9        2.3       0.14   80.0  12.9  7.42       1.0      17.0
# 226798  36.9        2.3       0.14   40.0  12.9  7.42       1.0      17.0
# 226799  36.9        2.3       0.14   45.0  12.9  7.42       1.0      17.0
#
#           SBP    DBP    MBP  male  female  surv_los   LOS  labels
# 0       116.0   58.0   77.0   1.0     0.0      -8.0   7.0     0.0
# 1       116.0   58.0   77.0   1.0     0.0      -8.0   7.0     0.0
# 2         0.0    0.0  224.0   1.0     0.0      -8.0   7.0     0.0
# 3         0.0    0.0  135.0   1.0     0.0      -8.0   7.0     0.0
# 4       217.0  108.0  133.0   1.0     0.0      -8.0   7.0     0.0
# ...       ...    ...    ...   ...     ...       ...   ...     ...
# 226795  118.0   66.0   85.0   1.0     0.0      -1.0  18.0     1.0
# 226796  129.0   71.0   93.0   1.0     0.0      -1.0  18.0     1.0
# 226797  114.0   65.0   84.0   1.0     0.0      -1.0  18.0     1.0
# 226798  111.0   61.0   80.0   1.0     0.0      -1.0  18.0     1.0
# 226799  109.0   62.0   80.0   1.0     0.0      -1.0  18.0     1.0
#
# [226800 rows x 43 columns]

# %%
# 'ICUType' 원-핫 인코딩

df6 = pd.get_dummies(df5, columns=['ICUType'])
print(len(df5.columns))
print(len(df6.columns))
print('ICUType' in df6.columns)
# Out:
# 43
# 46
# False

# %%
# X, y 분리
y_train = df6['labels']
X_train = df6.drop(columns=['pid', 'Gender', 'survival', 'surv_los', 'LOS', 'labels'])

print(y_train.shape)
print(X_train.shape)
# Out:
# (226800,)
# (226800, 40)

# %%
import tensorflow
